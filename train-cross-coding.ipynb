# %%
from transformers import AutoTokenizer , AutoConfig , AutoModelForSeq2SeqLM

# %%
model_name = "t5-small"
config = AutoConfig.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name , use_fast = True)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name , config = config)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Downloading model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
from datasets import load_dataset
dataset = load_dataset('findnitai/english-to-hinglish')
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
master = []
for line in dataset['train']['translation']:
    master.append(line['en'])
    master.append(line['hi_ng'])

def gen_training_data():
    return (master[i : i+500]
    for i in range(0, len(master), 500)
    )
tokenizer_training_data = gen_training_data()

# %%
tokenizer_training_data
# Out:
# <generator object gen_training_data.<locals>.<genexpr> at 0x7f8079eeb920>

# %%
trained_tokenizer = tokenizer.train_new_from_iterator(tokenizer_training_data , vocab_size = 32128)

# %%
trained_tokenizer.save_pretrained("english_to_hinglish_tokenizer")
# Out:
# ('english_to_hinglish_tokenizer/tokenizer_config.json',
#  'english_to_hinglish_tokenizer/special_tokens_map.json',
#  'english_to_hinglish_tokenizer/tokenizer.json')

# %%
source_prefix = "Translate English to Hinglish : "
source_lang = "en"
target_lang = "hi_ng"
max_source_length = 128 
max_target_length = 128 # target and source length task dependent (translation, summary etc.)
padding = "max_length" # padding to max length
num_epochs = 3

# %%
dataset_dict = dataset.data

# %%
output_json_path = "english_to_hinglish.json"

# %%
formatted_dataset = [{'translation':{"en": example["en"], "hi_ng": example["hi_ng"]}} for example in dataset['train']['translation']]

# %%
import json
with open(output_json_path, 'w', encoding='utf-8') as jsonl_file:
    for item in formatted_dataset :
        jsonl_file.write(json.dumps(item) + "\n")

# %%
raw_datasets = load_dataset(
    "json",
    data_files="english_to_hinglish.json",
  )
# Out:
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-a9faf385ec4e7638/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-a9faf385ec4e7638/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
def preprocess(source_data):
    inputs = [k[source_lang] for k in source_data['translation']]
    targets = [k[target_lang] for k in source_data['translation']]
    inputs = [source_prefix + inp for inp in inputs]
    #using the previously trained tokenizer
    model_inputs = trained_tokenizer(inputs, max_length=max_source_length, padding=padding, truncation=True)
    labels = trained_tokenizer(targets, max_length=max_target_length, padding=padding, truncation=True)

    labels["input_id"] = [
        [(l if l != tokenizer.pad_token_id else -100) for l in label] for label in labels["input_ids"]
    ]

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
raw_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['translation'],
#         num_rows: 189102
#     })
# })

# %%
train_dataset = raw_datasets["train"]

# %%
train_dataset = train_dataset.map(preprocess, batched=True, remove_columns="translation")
# Out:
#   0%|          | 0/190 [00:00<?, ?ba/s]

# %%
from transformers import default_data_collator

# %%
data_collator = default_data_collator

trainer_args_in = {
    'output_dir': 'full-hinglish-translator',
    'overwrite_output_dir' : True,
    'do_train' : True,
    # 'do_valid' : False,
    'per_device_train_batch_size' : 8,
    'num_train_epochs' : num_epochs,
}

# %%
from transformers import Seq2SeqTrainer, Seq2SeqTrainingArguments, HfArgumentParser
parser = HfArgumentParser((Seq2SeqTrainingArguments))
training_args = parser.parse_dict(trainer_args_in)

trainer = Seq2SeqTrainer(model=model, args=training_args[0], train_dataset=train_dataset, tokenizer=trained_tokenizer, data_collator=data_collator)

train_result = trainer.train(resume_from_checkpoint=None)
trainer.save_model()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb version 0.15.12 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>/kaggle/working/wandb/run-20231020_223315-fsoxve52</code>
# Syncing run <strong><a href='https://wandb.ai/profiecientvision/huggingface/runs/fsoxve52' target="_blank">stellar-pond-1</a></strong> to <a href='https://wandb.ai/profiecientvision/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/profiecientvision/huggingface' target="_blank">https://wandb.ai/profiecientvision/huggingface</a>
#  View run at <a href='https://wandb.ai/profiecientvision/huggingface/runs/fsoxve52' target="_blank">https://wandb.ai/profiecientvision/huggingface/runs/fsoxve52</a>
#     <div>
#
#       <progress value='14501' max='70914' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [14501/70914 26:07 < 1:41:37, 9.25 it/s, Epoch 0.61/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.829900</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.494900</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.451000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.429400</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.399500</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.395500</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.386200</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.369100</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.350600</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.350900</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.340100</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.325600</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.325100</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.319900</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.306400</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.302100</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.304200</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.291700</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.295500</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.284500</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.285000</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.287700</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.271000</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.262500</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.274400</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.268100</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.264500</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.257800</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/torch/serialization.py:441, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     440 with _open_zipfile_writer(f) as opened_zipfile:
# --> 441     _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     442     return
#
# File /opt/conda/lib/python3.10/site-packages/torch/serialization.py:668, in _save(obj, zip_file, pickle_module, pickle_protocol)
#     667 num_bytes = storage.nbytes()
# --> 668 zip_file.write_record(name, storage.data_ptr(), num_bytes)
#
# RuntimeError: [enforce fail at inline_container.cc:471] . PytorchStreamWriter failed writing file data/2: file write failed
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[25], line 7
#       3 training_args = parser.parse_dict(trainer_args_in)
#       5 trainer = Seq2SeqTrainer(model=model, args=training_args[0], train_dataset=train_dataset, tokenizer=trained_tokenizer, data_collator=data_collator)
# ----> 7 train_result = trainer.train(resume_from_checkpoint=None)
#       8 trainer.save_model()
#
# File /opt/conda/lib/python3.10/site-packages/transformers/trainer.py:1553, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1551         hf_hub_utils.enable_progress_bars()
#    1552 else:
# -> 1553     return inner_training_loop(
#    1554         args=args,
#    1555         resume_from_checkpoint=resume_from_checkpoint,
#    1556         trial=trial,
#    1557         ignore_keys_for_eval=ignore_keys_for_eval,
#    1558     )
#
# File /opt/conda/lib/python3.10/site-packages/transformers/trainer.py:1927, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1924     self.state.epoch = epoch + (step + 1 + steps_skipped) / steps_in_epoch
#    1925     self.control = self.callback_handler.on_step_end(args, self.state, self.control)
# -> 1927     self._maybe_log_save_evaluate(tr_loss, model, trial, epoch, ignore_keys_for_eval)
#    1928 else:
#    1929     self.control = self.callback_handler.on_substep_end(args, self.state, self.control)
#
# File /opt/conda/lib/python3.10/site-packages/transformers/trainer.py:2265, in Trainer._maybe_log_save_evaluate(self, tr_loss, model, trial, epoch, ignore_keys_for_eval)
#    2262         self.lr_scheduler.step(metrics[metric_to_check])
#    2264 if self.control.should_save:
# -> 2265     self._save_checkpoint(model, trial, metrics=metrics)
#    2266     self.control = self.callback_handler.on_save(self.args, self.state, self.control)
#
# File /opt/conda/lib/python3.10/site-packages/transformers/trainer.py:2362, in Trainer._save_checkpoint(self, model, trial, metrics)
#    2354         smp.save(
#    2355             opt_state_dict,
#    2356             os.path.join(output_dir, OPTIMIZER_NAME),
#    2357             partial=True,
#    2358             v3=smp.state.cfg.shard_optimizer_state,
#    2359         )
#    2360 elif self.args.should_save and not self.is_deepspeed_enabled and not (self.fsdp or self.is_fsdp_enabled):
#    2361     # deepspeed.save_checkpoint above saves model/optim/sched
# -> 2362     torch.save(self.optimizer.state_dict(), os.path.join(output_dir, OPTIMIZER_NAME))
#    2364 # Save SCHEDULER & SCALER
#    2365 if self.args.should_save and not self.is_deepspeed_enabled and not is_torch_tpu_available():
#
# File /opt/conda/lib/python3.10/site-packages/torch/serialization.py:440, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     437 _check_save_filelike(f)
#     439 if _use_new_zipfile_serialization:
# --> 440     with _open_zipfile_writer(f) as opened_zipfile:
#     441         _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     442         return
#
# File /opt/conda/lib/python3.10/site-packages/torch/serialization.py:291, in _open_zipfile_writer_file.__exit__(self, *args)
#     290 def __exit__(self, *args) -> None:
# --> 291     self.file_like.write_end_of_file()
#
# RuntimeError: [enforce fail at inline_container.cc:337] . unexpected pos 200064704 vs 200064592
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 1104, in emit
#     self.flush()
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 1084, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/opt/conda/lib/python3.10/threading.py", line 973, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/conda/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/opt/conda/lib/python3.10/site-packages/wandb/sdk/internal/internal_util.py", line 49, in run
#     self._run()
#   File "/opt/conda/lib/python3.10/site-packages/wandb/sdk/internal/internal_util.py", line 100, in _run
#     self._process(record)
#   File "/opt/conda/lib/python3.10/site-packages/wandb/sdk/internal/internal.py", line 279, in _process
#     self._hm.handle(record)
#   File "/opt/conda/lib/python3.10/site-packages/wandb/sdk/internal/handler.py", line 136, in handle
#     handler(record)
#   File "/opt/conda/lib/python3.10/site-packages/wandb/sdk/internal/handler.py", line 144, in handle_request
#     logger.debug(f"handle_request: {request_type}")
# Message: 'handle_request: keepalive'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 1104, in emit
#     self.flush()
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 1084, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/opt/conda/lib/python3.10/threading.py", line 973, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/conda/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/opt/conda/lib/python3.10/site-packages/wandb/sdk/internal/internal_util.py", line 49, in run
#     self._run()
#   File "/opt/conda/lib/python3.10/site-packages/wandb/sdk/internal/internal_util.py", line 101, in _run
#     self._finish()
#   File "/opt/conda/lib/python3.10/site-packages/wandb/sdk/internal/internal.py", line 331, in _finish
#     self._sm.finish()
#   File "/opt/conda/lib/python3.10/site-packages/wandb/sdk/internal/sender.py", line 1552, in finish
#     logger.info("shutting down sender")
# Message: 'shutting down sender'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 1104, in emit
#     self.flush()
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 1084, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/opt/conda/lib/python3.10/threading.py", line 973, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/conda/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/opt/conda/lib/python3.10/site-packages/wandb/sdk/internal/internal_util.py", line 49, in run
#     self._run()
#   File "/opt/conda/lib/python3.10/site-packages/wandb/sdk/internal/internal_util.py", line 101, in _run
#     self._finish()
#   File "/opt/conda/lib/python3.10/site-packages/wandb/sdk/internal/internal.py", line 282, in _finish
#     self._hm.finish()
#   File "/opt/conda/lib/python3.10/site-packages/wandb/sdk/internal/handler.py", line 861, in finish
#     logger.info("shutting down handler")
# Message: 'shutting down handler'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 1104, in emit
#     self.flush()
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 1084, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/opt/conda/lib/python3.10/threading.py", line 973, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/conda/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/opt/conda/lib/python3.10/site-packages/wandb/vendor/watchdog_0_9_0/wandb_watchdog/observers/api.py", line 199, in run
#     self.dispatch_events(self.event_queue, self.timeout)
#   File "/opt/conda/lib/python3.10/site-packages/wandb/vendor/watchdog_0_9_0/wandb_watchdog/observers/api.py", line 368, in dispatch_events
#     handler.dispatch(event)
#   File "/opt/conda/lib/python3.10/site-packages/wandb/vendor/watchdog_0_9_0/wandb_watchdog/events.py", line 454, in dispatch
#     _method_map[event_type](event)
#   File "/opt/conda/lib/python3.10/site-packages/wandb/filesync/dir_watcher.py", line 271, in _on_file_created
#     logger.info("file/dir created: %s", event.src_path)
# Message: 'file/dir created: %s'
# Arguments: ('/kaggle/working/wandb/run-20231020_223315-fsoxve52/files/output.log',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 1104, in emit
#     self.flush()
#   File "/opt/conda/lib/python3.10/logging/__init__.py", line 1084, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/opt/conda/lib/python3.10/threading.py", line 973, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/conda/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/opt/conda/lib/python3.10/site-packages/wandb/sdk/service/streams.py", line 48, in run
#     self._target(**self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/wandb/sdk/internal/internal.py", line 174, in wandb_internal
#     logger.error(f"Thread {thread.name}:", exc_info=exc_info)
# Message: 'Thread SenderThread:'
# Arguments: ()
# Thread SenderThread:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/wandb/sdk/internal/internal_util.py", line 49, in run
#     self._run()
#   File "/opt/conda/lib/python3.10/site-packages/wandb/sdk/internal/internal_util.py", line 101, in _run
#     self._finish()
#   File "/opt/conda/lib/python3.10/site-packages/wandb/sdk/internal/internal.py", line 331, in _finish
#     self._sm.finish()
#   File "/opt/conda/lib/python3.10/site-packages/wandb/sdk/internal/sender.py", line 1555, in finish
#     self._output_raw_finish()
#   File "/opt/conda/lib/python3.10/site-packages/wandb/sdk/internal/sender.py", line 1194, in _output_raw_finish
#     self._output_raw_flush(stream)
#   File "/opt/conda/lib/python3.10/site-packages/wandb/sdk/internal/sender.py", line 1241, in _output_raw_flush
#     self._output_raw_file.write(data.encode("utf-8"))
#   File "/opt/conda/lib/python3.10/site-packages/wandb/sdk/lib/filesystem.py", line 79, in write
#     super().write(b"\n".join(ret) + b"\n")
#   File "/opt/conda/lib/python3.10/site-packages/wandb/sdk/lib/filesystem.py", line 46, in write
#     self.f.flush()
# OSError: [Errno 28] No space left on device
# wandb: ERROR Internal wandb error: file data was not synced
